# %%
from serpapi import Client
import os
from dotenv import load_dotenv
load_dotenv(".env")
# Out:
# True

# %%
search_client = Client(api_key=os.getenv("SERP_API_KEY"))

# search_client
params = {
  "engine": "google_scholar",
  "q": "machine learning",
  "hl": "en",
  "as_ylo": "2019"
}

# search = Client(params)
# results = search.get_dict()
# organic_results = results["organic_results"]

# %%
search_client.search(params)
# Out:
# {
#     "search_metadata": {
#         "id": "69ae864bd10c6a808dfacb90",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/4n45FIqhv2yIiN2sgmS1BQ/69ae864bd10c6a808dfacb90.json",
#         "created_at": "2026-03-09 08:35:23 UTC",
#         "processed_at": "2026-03-09 08:35:23 UTC",
#         "google_scholar_url": "https://scholar.google.com/scholar?q=machine+learning&hl=en&as_ylo=2019",
#         "raw_html_file": "https://serpapi.com/searches/4n45FIqhv2yIiN2sgmS1BQ/69ae864bd10c6a808dfacb90.html",
#         "total_time_taken": 2.94
#     },
#     "search_parameters": {
#         "engine": "google_scholar",
#         "q": "machine learning",
#         "hl": "en",
#         "as_ylo": "2019"
#     },
#     "search_information": {
#         "organic_results_state": "Results for exact spelling",
#         "total_results": 1650000,
#         "time_taken_displayed": 0.1,
#         "query_displayed": "machine learning"
#     },
#     "organic_results": [
# ...

# %%
results = """
{
    "search_metadata": {
        "id": "69ae864bd10c6a808dfacb90",
        "status": "Success",
        "json_endpoint": "https://serpapi.com/searches/4n45FIqhv2yIiN2sgmS1BQ/69ae864bd10c6a808dfacb90.json",
        "created_at": "2026-03-09 08:35:23 UTC",
        "processed_at": "2026-03-09 08:35:23 UTC",
        "google_scholar_url": "https://scholar.google.com/scholar?q=machine+learning&hl=en&as_ylo=2019",
        "raw_html_file": "https://serpapi.com/searches/4n45FIqhv2yIiN2sgmS1BQ/69ae864bd10c6a808dfacb90.html",
        "total_time_taken": 2.94
    },
    "search_parameters": {
        "engine": "google_scholar",
        "q": "machine learning",
        "hl": "en",
        "as_ylo": "2019"
    },
    "search_information": {
        "organic_results_state": "Results for exact spelling",
        "total_results": 1650000,
        "time_taken_displayed": 0.1,
        "query_displayed": "machine learning"
    },
    "organic_results": [
        {
            "position": 1,
            "title": "Machine learning",
            "result_id": "EQ8shYj8Ai8J",
            "type": "Book",
            "link": "https://books.google.com/books?hl=en&lr=&id=ctM-EAAAQBAJ&oi=fnd&pg=PR6&dq=machine+learning&ots=o_PkT3Qx_r&sig=zRKdIVneWMQB1TKFwR8Hv64rqMU",
            "snippet": "\u2026 from data is called learning or training. The \u2026 machine learning is to find or approximate ground-truth. In this book, models are sometimes called learners, which are machine learning \u2026",
            "publication_info": {
                "summary": "ZH Zhou - 2021 - books.google.com",
                "authors": [
                    {
                        "name": "ZH Zhou",
                        "link": "https://scholar.google.com/citations?user=rSVIHasAAAAJ&hl=en&oi=sra",
                        "author_id": "rSVIHasAAAAJ",
                        "serpapi_scholar_link": "https://serpapi.com/search.json?author_id=rSVIHasAAAAJ&engine=google_scholar_author&hl=en"
                    }
                ]
            },
            "inline_links": {
                "serpapi_cite_link": "https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=EQ8shYj8Ai8J",
                "cited_by": {
                    "total": 3612,
                    "link": "https://scholar.google.com/scholar?cites=3387547533016043281&as_sdt=400005&sciodt=0,14&hl=en",
                    "cites_id": "3387547533016043281",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=400005&cites=3387547533016043281&engine=google_scholar&hl=en"
                },
                "related_pages_link": "https://scholar.google.com/scholar?q=related:EQ8shYj8Ai8J:scholar.google.com/&scioq=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
                "serpapi_related_pages_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=related%3AEQ8shYj8Ai8J%3Ascholar.google.com%2F",
                "versions": {
                    "total": 7,
                    "link": "https://scholar.google.com/scholar?cluster=3387547533016043281&hl=en&as_sdt=0,14&as_ylo=2019",
                    "cluster_id": "3387547533016043281",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&cluster=3387547533016043281&engine=google_scholar&hl=en"
                }
            }
        },
        {
            "position": 2,
            "title": "Machine learning",
            "result_id": "_zuqxloS2b0J",
            "type": "Book",
            "link": "https://books.google.com/books?hl=en&lr=&id=Eyk5EAAAQBAJ&oi=fnd&pg=PA1&dq=machine+learning&ots=WRzMbcVmqO&sig=DIw4JfaJgaEsEdTPsL8GDeKpw58",
            "snippet": "MIT presents a concise primer on machine learning\u2014computer programs that learn from data and the basis of applications like voice recognition and driverless cars. No in-depth \u2026",
            "publication_info": {
                "summary": "E Alpaydin - 2021 - books.google.com",
                "authors": [
                    {
                        "name": "E Alpaydin"
                    }
                ]
            },
            "resources": [
                {
                    "title": "pomona.edu",
                    "file_format": "PDF",
                    "link": "https://cs.pomona.edu/~dkauchak/classes/s16/cs30-s16/lectures/lecture12-NN-basics.pdf"
                }
            ],
            "inline_links": {
                "serpapi_cite_link": "https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=_zuqxloS2b0J",
                "cited_by": {
                    "total": 1617,
                    "link": "https://scholar.google.com/scholar?cites=13679985524203994111&as_sdt=400005&sciodt=0,14&hl=en",
                    "cites_id": "13679985524203994111",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=400005&cites=13679985524203994111&engine=google_scholar&hl=en"
                },
                "related_pages_link": "https://scholar.google.com/scholar?q=related:_zuqxloS2b0J:scholar.google.com/&scioq=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
                "serpapi_related_pages_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=related%3A_zuqxloS2b0J%3Ascholar.google.com%2F",
                "versions": {
                    "total": 9,
                    "link": "https://scholar.google.com/scholar?cluster=13679985524203994111&hl=en&as_sdt=0,14&as_ylo=2019",
                    "cluster_id": "13679985524203994111",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&cluster=13679985524203994111&engine=google_scholar&hl=en"
                }
            }
        },
        {
            "position": 3,
            "title": "Machine learning algorithms: a review",
            "result_id": "TVVEPP7WNfUJ",
            "type": "Pdf",
            "link": "https://www.academia.edu/download/59817925/IRJET-V6I217620190621-73452-h5pwu7.pdf",
            "snippet": "\u2026 There are a wide range of applications of machine learning methods \u2026 the overview of different machine learning approaches. \u2026 Unsupervised learning is a class of machine learning that \u2026",
            "publication_info": {
                "summary": "D Pandey, K Niwaria, B Chourasia - Mach. Learn, 2019 - academia.edu",
                "authors": [
                    {
                        "name": "D Pandey"
                    },
                    {
                        "name": "K Niwaria"
                    },
                    {
                        "name": "B Chourasia"
                    }
                ]
            },
            "resources": [
                {
                    "title": "academia.edu",
                    "file_format": "PDF",
                    "link": "https://www.academia.edu/download/59817925/IRJET-V6I217620190621-73452-h5pwu7.pdf"
                }
            ],
            "inline_links": {
                "serpapi_cite_link": "https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=TVVEPP7WNfUJ",
                "cited_by": {
                    "total": 5603,
                    "link": "https://scholar.google.com/scholar?cites=17669265100479157581&as_sdt=400005&sciodt=0,14&hl=en",
                    "cites_id": "17669265100479157581",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=400005&cites=17669265100479157581&engine=google_scholar&hl=en"
                },
                "related_pages_link": "https://scholar.google.com/scholar?q=related:TVVEPP7WNfUJ:scholar.google.com/&scioq=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
                "serpapi_related_pages_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=related%3ATVVEPP7WNfUJ%3Ascholar.google.com%2F",
                "versions": {
                    "total": 6,
                    "link": "https://scholar.google.com/scholar?cluster=17669265100479157581&hl=en&as_sdt=0,14&as_ylo=2019",
                    "cluster_id": "17669265100479157581",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&cluster=17669265100479157581&engine=google_scholar&hl=en"
                },
                "cached_page_link": "https://scholar.googleusercontent.com/scholar?q=cache:TVVEPP7WNfUJ:scholar.google.com/+machine+learning&hl=en&as_sdt=0,14&as_ylo=2019"
            }
        },
        {
            "position": 4,
            "title": "Machine learning for nanoplasmonics",
            "result_id": "zvluJjI4v2cJ",
            "link": "https://www.nature.com/articles/s41565-022-01284-0",
            "snippet": "\u2026 These complex datasets and trial-and-error practices make nanoplasmonics research ripe for the application of machine learning (ML) and advanced data processing methods. ML \u2026",
            "publication_info": {
                "summary": "JF Masson, JS Biggins, E Ringe - Nature Nanotechnology, 2023 - nature.com",
                "authors": [
                    {
                        "name": "JF Masson",
                        "link": "https://scholar.google.com/citations?user=ENzuD4gAAAAJ&hl=en&oi=sra",
                        "author_id": "ENzuD4gAAAAJ",
                        "serpapi_scholar_link": "https://serpapi.com/search.json?author_id=ENzuD4gAAAAJ&engine=google_scholar_author&hl=en"
                    },
                    {
                        "name": "JS Biggins",
                        "link": "https://scholar.google.com/citations?user=J5TlRyEAAAAJ&hl=en&oi=sra",
                        "author_id": "J5TlRyEAAAAJ",
                        "serpapi_scholar_link": "https://serpapi.com/search.json?author_id=J5TlRyEAAAAJ&engine=google_scholar_author&hl=en"
                    },
                    {
                        "name": "E Ringe",
                        "link": "https://scholar.google.com/citations?user=05E4Sz8AAAAJ&hl=en&oi=sra",
                        "author_id": "05E4Sz8AAAAJ",
                        "serpapi_scholar_link": "https://serpapi.com/search.json?author_id=05E4Sz8AAAAJ&engine=google_scholar_author&hl=en"
                    }
                ]
            },
            "resources": [
                {
                    "title": "cam.ac.uk",
                    "file_format": "DOC",
                    "link": "https://www.repository.cam.ac.uk/bitstreams/21b3addd-ba8b-4c9c-bc46-6e45ba8cca6a/download"
                }
            ],
            "inline_links": {
                "serpapi_cite_link": "https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=zvluJjI4v2cJ",
                "cited_by": {
                    "total": 132,
                    "link": "https://scholar.google.com/scholar?cites=7475755694502640078&as_sdt=400005&sciodt=0,14&hl=en",
                    "cites_id": "7475755694502640078",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=400005&cites=7475755694502640078&engine=google_scholar&hl=en"
                },
                "related_pages_link": "https://scholar.google.com/scholar?q=related:zvluJjI4v2cJ:scholar.google.com/&scioq=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
                "serpapi_related_pages_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=related%3AzvluJjI4v2cJ%3Ascholar.google.com%2F",
                "versions": {
                    "total": 8,
                    "link": "https://scholar.google.com/scholar?cluster=7475755694502640078&hl=en&as_sdt=0,14&as_ylo=2019",
                    "cluster_id": "7475755694502640078",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&cluster=7475755694502640078&engine=google_scholar&hl=en"
                }
            }
        },
        {
            "position": 5,
            "title": "Machine learning and the physical sciences",
            "result_id": "eucrqVB_bisJ",
            "link": "https://journals.aps.org/rmp/abstract/10.1103/RevModPhys.91.045002",
            "snippet": "\u2026 II, where the interaction with machine learning has a long history, drawing on methods in \u2026 in machine learning. We then turn the wheel in the other direction of using machine learning for \u2026",
            "publication_info": {
                "summary": "G Carleo, I Cirac, K Cranmer, L Daudet, M Schuld\u2026 - Reviews of Modern \u2026, 2019 - APS",
                "authors": [
                    {
                        "name": "G Carleo",
                        "link": "https://scholar.google.com/citations?user=e9I38PEAAAAJ&hl=en&oi=sra",
                        "author_id": "e9I38PEAAAAJ",
                        "serpapi_scholar_link": "https://serpapi.com/search.json?author_id=e9I38PEAAAAJ&engine=google_scholar_author&hl=en"
                    },
                    {
                        "name": "I Cirac",
                        "link": "https://scholar.google.com/citations?user=gPGlTbgAAAAJ&hl=en&oi=sra",
                        "author_id": "gPGlTbgAAAAJ",
                        "serpapi_scholar_link": "https://serpapi.com/search.json?author_id=gPGlTbgAAAAJ&engine=google_scholar_author&hl=en"
                    },
                    {
                        "name": "K Cranmer",
                        "link": "https://scholar.google.com/citations?user=EZjSxgwAAAAJ&hl=en&oi=sra",
                        "author_id": "EZjSxgwAAAAJ",
                        "serpapi_scholar_link": "https://serpapi.com/search.json?author_id=EZjSxgwAAAAJ&engine=google_scholar_author&hl=en"
                    },
                    {
                        "name": "L Daudet",
                        "link": "https://scholar.google.com/citations?user=PCIAcfUAAAAJ&hl=en&oi=sra",
                        "author_id": "PCIAcfUAAAAJ",
                        "serpapi_scholar_link": "https://serpapi.com/search.json?author_id=PCIAcfUAAAAJ&engine=google_scholar_author&hl=en"
                    },
                    {
                        "name": "M Schuld",
                        "link": "https://scholar.google.com/citations?user=_ih_hwUAAAAJ&hl=en&oi=sra",
                        "author_id": "_ih_hwUAAAAJ",
                        "serpapi_scholar_link": "https://serpapi.com/search.json?author_id=_ih_hwUAAAAJ&engine=google_scholar_author&hl=en"
                    }
                ]
            },
            "resources": [
                {
                    "title": "aps.org",
                    "file_format": "PDF",
                    "link": "https://link.aps.org/accepted/10.1103/RevModPhys.91.045002"
                }
            ],
            "inline_links": {
                "serpapi_cite_link": "https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=eucrqVB_bisJ",
                "cited_by": {
                    "total": 3219,
                    "link": "https://scholar.google.com/scholar?cites=3129578775481411450&as_sdt=400005&sciodt=0,14&hl=en",
                    "cites_id": "3129578775481411450",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=400005&cites=3129578775481411450&engine=google_scholar&hl=en"
                },
                "related_pages_link": "https://scholar.google.com/scholar?q=related:eucrqVB_bisJ:scholar.google.com/&scioq=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
                "serpapi_related_pages_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=related%3AeucrqVB_bisJ%3Ascholar.google.com%2F",
                "versions": {
                    "total": 15,
                    "link": "https://scholar.google.com/scholar?cluster=3129578775481411450&hl=en&as_sdt=0,14&as_ylo=2019",
                    "cluster_id": "3129578775481411450",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&cluster=3129578775481411450&engine=google_scholar&hl=en"
                }
            }
        },
        {
            "position": 6,
            "title": "What is machine learning? A primer for the epidemiologist",
            "result_id": "LDE5SAcBB-gJ",
            "link": "https://academic.oup.com/aje/article-abstract/188/12/2222/5567515",
            "snippet": "\u2026 We provide a brief introduction to 5 common machine learning \u2026 of machine learning techniques in the published literature. We recommend approaches to incorporate machine learning \u2026",
            "publication_info": {
                "summary": "Q Bi, KE Goodman, J Kaminsky\u2026 - American journal of \u2026, 2019 - academic.oup.com",
                "authors": [
                    {
                        "name": "Q Bi",
                        "link": "https://scholar.google.com/citations?user=xzss3t0AAAAJ&hl=en&oi=sra",
                        "author_id": "xzss3t0AAAAJ",
                        "serpapi_scholar_link": "https://serpapi.com/search.json?author_id=xzss3t0AAAAJ&engine=google_scholar_author&hl=en"
                    },
                    {
                        "name": "KE Goodman"
                    },
                    {
                        "name": "J Kaminsky",
                        "link": "https://scholar.google.com/citations?user=BFdcm_gAAAAJ&hl=en&oi=sra",
                        "author_id": "BFdcm_gAAAAJ",
                        "serpapi_scholar_link": "https://serpapi.com/search.json?author_id=BFdcm_gAAAAJ&engine=google_scholar_author&hl=en"
                    }
                ]
            },
            "inline_links": {
                "serpapi_cite_link": "https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=LDE5SAcBB-gJ",
                "cited_by": {
                    "total": 858,
                    "link": "https://scholar.google.com/scholar?cites=16719333272424362284&as_sdt=400005&sciodt=0,14&hl=en",
                    "cites_id": "16719333272424362284",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=400005&cites=16719333272424362284&engine=google_scholar&hl=en"
                },
                "related_pages_link": "https://scholar.google.com/scholar?q=related:LDE5SAcBB-gJ:scholar.google.com/&scioq=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
                "serpapi_related_pages_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=related%3ALDE5SAcBB-gJ%3Ascholar.google.com%2F",
                "versions": {
                    "total": 10,
                    "link": "https://scholar.google.com/scholar?cluster=16719333272424362284&hl=en&as_sdt=0,14&as_ylo=2019",
                    "cluster_id": "16719333272424362284",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&cluster=16719333272424362284&engine=google_scholar&hl=en"
                }
            }
        },
        {
            "position": 7,
            "title": "International conference on machine learning",
            "result_id": "gUoVCWuQbkcJ",
            "type": "Pdf",
            "link": "https://par.nsf.gov/servlets/purl/10418406",
            "snippet": "In this paper, we make the key delineation on the roles of resolution and statistical uncertainty in hierarchical bandits-based black-box optimization algorithms, guiding a more general \u2026",
            "publication_info": {
                "summary": "W Li, C Wang, G Cheng, Q Song - Transactions on machine learning \u2026, 2023 - par.nsf.gov",
                "authors": [
                    {
                        "name": "W Li"
                    },
                    {
                        "name": "C Wang"
                    },
                    {
                        "name": "G Cheng"
                    },
                    {
                        "name": "Q Song"
                    }
                ]
            },
            "resources": [
                {
                    "title": "nsf.gov",
                    "file_format": "PDF",
                    "link": "https://par.nsf.gov/servlets/purl/10418406"
                }
            ],
            "inline_links": {
                "serpapi_cite_link": "https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=gUoVCWuQbkcJ",
                "cited_by": {
                    "total": 3309,
                    "link": "https://scholar.google.com/scholar?cites=5147210213519346305&as_sdt=400005&sciodt=0,14&hl=en",
                    "cites_id": "5147210213519346305",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=400005&cites=5147210213519346305&engine=google_scholar&hl=en"
                },
                "related_pages_link": "https://scholar.google.com/scholar?q=related:gUoVCWuQbkcJ:scholar.google.com/&scioq=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
                "serpapi_related_pages_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=related%3AgUoVCWuQbkcJ%3Ascholar.google.com%2F",
                "cached_page_link": "https://scholar.googleusercontent.com/scholar?q=cache:gUoVCWuQbkcJ:scholar.google.com/+machine+learning&hl=en&as_sdt=0,14&as_ylo=2019"
            }
        },
        {
            "position": 8,
            "title": "What is machine learning?",
            "result_id": "OsB2qindikUJ",
            "link": "https://onlinelibrary.wiley.com/doi/abs/10.1002/9781119815075.ch18",
            "snippet": "\u2026 that one can employ in machine learning (ML). The required \u2026 of two learning types: supervised or unsupervised learning. \u2026 skills through either automated learning or learning via human \u2026",
            "publication_info": {
                "summary": "J Bell - Machine learning and the city: applications in \u2026, 2022 - Wiley Online Library",
                "authors": [
                    {
                        "name": "J Bell"
                    }
                ]
            },
            "inline_links": {
                "serpapi_cite_link": "https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=OsB2qindikUJ",
                "cited_by": {
                    "total": 162,
                    "link": "https://scholar.google.com/scholar?cites=5011060706426404922&as_sdt=400005&sciodt=0,14&hl=en",
                    "cites_id": "5011060706426404922",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=400005&cites=5011060706426404922&engine=google_scholar&hl=en"
                },
                "related_pages_link": "https://scholar.google.com/scholar?q=related:OsB2qindikUJ:scholar.google.com/&scioq=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
                "serpapi_related_pages_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=related%3AOsB2qindikUJ%3Ascholar.google.com%2F",
                "versions": {
                    "total": 4,
                    "link": "https://scholar.google.com/scholar?cluster=5011060706426404922&hl=en&as_sdt=0,14&as_ylo=2019",
                    "cluster_id": "5011060706426404922",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&cluster=5011060706426404922&engine=google_scholar&hl=en"
                }
            }
        },
        {
            "position": 9,
            "title": "Amnesiac machine learning",
            "result_id": "8JpyOA74dtgJ",
            "link": "https://ojs.aaai.org/index.php/AAAI/article/view/17371",
            "snippet": "\u2026 It gives EU residents the ability to request deletion of their personal data, including training records used to train machine learning models. Unfortunately, Deep Neural Network models \u2026",
            "publication_info": {
                "summary": "L Graves, V Nagisetty, V Ganesh - \u2026 of the AAAI conference on artificial \u2026, 2021 - ojs.aaai.org",
                "authors": [
                    {
                        "name": "L Graves",
                        "link": "https://scholar.google.com/citations?user=uTrKxm8AAAAJ&hl=en&oi=sra",
                        "author_id": "uTrKxm8AAAAJ",
                        "serpapi_scholar_link": "https://serpapi.com/search.json?author_id=uTrKxm8AAAAJ&engine=google_scholar_author&hl=en"
                    },
                    {
                        "name": "V Nagisetty",
                        "link": "https://scholar.google.com/citations?user=9CaiG4UAAAAJ&hl=en&oi=sra",
                        "author_id": "9CaiG4UAAAAJ",
                        "serpapi_scholar_link": "https://serpapi.com/search.json?author_id=9CaiG4UAAAAJ&engine=google_scholar_author&hl=en"
                    },
                    {
                        "name": "V Ganesh",
                        "link": "https://scholar.google.com/citations?user=YP23eR0AAAAJ&hl=en&oi=sra",
                        "author_id": "YP23eR0AAAAJ",
                        "serpapi_scholar_link": "https://serpapi.com/search.json?author_id=YP23eR0AAAAJ&engine=google_scholar_author&hl=en"
                    }
                ]
            },
            "resources": [
                {
                    "title": "aaai.org",
                    "file_format": "PDF",
                    "link": "https://ojs.aaai.org/index.php/AAAI/article/download/17371/17178"
                }
            ],
            "inline_links": {
                "serpapi_cite_link": "https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=8JpyOA74dtgJ",
                "cited_by": {
                    "total": 510,
                    "link": "https://scholar.google.com/scholar?cites=15597927099404557040&as_sdt=400005&sciodt=0,14&hl=en",
                    "cites_id": "15597927099404557040",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=400005&cites=15597927099404557040&engine=google_scholar&hl=en"
                },
                "related_pages_link": "https://scholar.google.com/scholar?q=related:8JpyOA74dtgJ:scholar.google.com/&scioq=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
                "serpapi_related_pages_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=related%3A8JpyOA74dtgJ%3Ascholar.google.com%2F",
                "versions": {
                    "total": 7,
                    "link": "https://scholar.google.com/scholar?cluster=15597927099404557040&hl=en&as_sdt=0,14&as_ylo=2019",
                    "cluster_id": "15597927099404557040",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&cluster=15597927099404557040&engine=google_scholar&hl=en"
                },
                "cached_page_link": "https://scholar.googleusercontent.com/scholar?q=cache:8JpyOA74dtgJ:scholar.google.com/+machine+learning&hl=en&as_sdt=0,14&as_ylo=2019"
            }
        },
        {
            "position": 10,
            "title": "The hundred-page machine learning book",
            "result_id": "JLoaFgwmnQcJ",
            "type": "Book",
            "link": "https://order-papers.com/sites/default/files/tmp/webform/order_download/pdf-the-hundred-page-machine-learning-book-andriy-burkov-pdf-download-free-book-d835289.pdf",
            "snippet": "The book is divided into a three chapters and one that got the time. Because it dreamed of a dog i would be very proud to the actual story. When you get knowing you do n't listen to what \u2026",
            "publication_info": {
                "summary": "A Burkov - 2019 - order-papers.com",
                "authors": [
                    {
                        "name": "A Burkov"
                    }
                ]
            },
            "resources": [
                {
                    "title": "order-papers.com",
                    "file_format": "PDF",
                    "link": "https://order-papers.com/sites/default/files/tmp/webform/order_download/pdf-the-hundred-page-machine-learning-book-andriy-burkov-pdf-download-free-book-d835289.pdf"
                }
            ],
            "inline_links": {
                "serpapi_cite_link": "https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=JLoaFgwmnQcJ",
                "cited_by": {
                    "total": 1439,
                    "link": "https://scholar.google.com/scholar?cites=548636562961381924&as_sdt=400005&sciodt=0,14&hl=en",
                    "cites_id": "548636562961381924",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=400005&cites=548636562961381924&engine=google_scholar&hl=en"
                },
                "related_pages_link": "https://scholar.google.com/scholar?q=related:JLoaFgwmnQcJ:scholar.google.com/&scioq=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
                "serpapi_related_pages_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=related%3AJLoaFgwmnQcJ%3Ascholar.google.com%2F",
                "versions": {
                    "total": 4,
                    "link": "https://scholar.google.com/scholar?cluster=548636562961381924&hl=en&as_sdt=0,14&as_ylo=2019",
                    "cluster_id": "548636562961381924",
                    "serpapi_scholar_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&cluster=548636562961381924&engine=google_scholar&hl=en"
                },
                "cached_page_link": "https://scholar.googleusercontent.com/scholar?q=cache:JLoaFgwmnQcJ:scholar.google.com/+machine+learning&hl=en&as_sdt=0,14&as_ylo=2019"
            }
        }
    ],
    "related_searches": [
        {
            "query": "machine learning prediction",
            "link": "https://scholar.google.com/scholar?hl=en&as_sdt=0,14&qsp=1&q=machine+learning+prediction&qst=ib"
        },
        {
            "query": "machine learning algorithms",
            "link": "https://scholar.google.com/scholar?hl=en&as_sdt=0,14&qsp=2&q=machine+learning+algorithms&qst=ib"
        },
        {
            "query": "supervised machine learning",
            "link": "https://scholar.google.com/scholar?hl=en&as_sdt=0,14&qsp=3&q=supervised+machine+learning&qst=ib"
        },
        {
            "query": "interpretable machine learning",
            "link": "https://scholar.google.com/scholar?hl=en&as_sdt=0,14&qsp=4&q=interpretable+machine+learning&qst=ib"
        },
        {
            "query": "pattern recognition machine learning",
            "link": "https://scholar.google.com/scholar?hl=en&as_sdt=0,14&qsp=5&q=pattern+recognition+machine+learning&qst=ib"
        },
        {
            "query": "malware detection machine learning",
            "link": "https://scholar.google.com/scholar?hl=en&as_sdt=0,14&qsp=6&q=malware+detection+machine+learning&qst=ib"
        },
        {
            "query": "fake news detection machine learning",
            "link": "https://scholar.google.com/scholar?hl=en&as_sdt=0,14&qsp=7&q=fake+news+detection+machine+learning&qst=ib"
        },
        {
            "query": "physics informed machine learning",
            "link": "https://scholar.google.com/scholar?hl=en&as_sdt=0,14&qsp=8&q=physics+informed+machine+learning&qst=ib"
        }
    ],
    "pagination": {
        "current": 1,
        "next": "https://scholar.google.com/scholar?start=10&q=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
        "other_pages": {
            "2": "https://scholar.google.com/scholar?start=10&q=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
            "3": "https://scholar.google.com/scholar?start=20&q=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
            "4": "https://scholar.google.com/scholar?start=30&q=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
            "5": "https://scholar.google.com/scholar?start=40&q=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
            "6": "https://scholar.google.com/scholar?start=50&q=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
            "7": "https://scholar.google.com/scholar?start=60&q=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
            "8": "https://scholar.google.com/scholar?start=70&q=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
            "9": "https://scholar.google.com/scholar?start=80&q=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019",
            "10": "https://scholar.google.com/scholar?start=90&q=machine+learning&hl=en&as_sdt=0,14&as_ylo=2019"
        }
    },
    "serpapi_pagination": {
        "current": 1,
        "next_link": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=machine+learning&start=10",
        "next": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=machine+learning&start=10",
        "other_pages": {
            "2": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=machine+learning&start=10",
            "3": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=machine+learning&start=20",
            "4": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=machine+learning&start=30",
            "5": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=machine+learning&start=40",
            "6": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=machine+learning&start=50",
            "7": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=machine+learning&start=60",
            "8": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=machine+learning&start=70",
            "9": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=machine+learning&start=80",
            "10": "https://serpapi.com/search.json?as_sdt=0%2C14&as_ylo=2019&engine=google_scholar&hl=en&q=machine+learning&start=90"
        }
    }
}
"""

# %%
import json
result_json=json.loads(results)

# %%
print(json.dumps(result_json, indent=4))
# Out:
# {
#     "search_metadata": {
#         "id": "69ae864bd10c6a808dfacb90",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/4n45FIqhv2yIiN2sgmS1BQ/69ae864bd10c6a808dfacb90.json",
#         "created_at": "2026-03-09 08:35:23 UTC",
#         "processed_at": "2026-03-09 08:35:23 UTC",
#         "google_scholar_url": "https://scholar.google.com/scholar?q=machine+learning&hl=en&as_ylo=2019",
#         "raw_html_file": "https://serpapi.com/searches/4n45FIqhv2yIiN2sgmS1BQ/69ae864bd10c6a808dfacb90.html",
#         "total_time_taken": 2.94
#     },
#     "search_parameters": {
#         "engine": "google_scholar",
#         "q": "machine learning",
#         "hl": "en",
#         "as_ylo": "2019"
#     },
#     "search_information": {
#         "organic_results_state": "Results for exact spelling",
#         "total_results": 1650000,
#         "time_taken_displayed": 0.1,
#         "query_displayed": "machine learning"
#     },
#     "organic_results": [
# ...

# %%
from src.util.llm_util import get_llm
llm = get_llm()
x = llm.invoke("Hello")

# %%
print(x.model_dump_json(indent=4))
# Out:
# {
#     "content": "Hello there! How can I help you today?",
#     "additional_kwargs": {},
#     "response_metadata": {
#         "finish_reason": "STOP",
#         "model_name": "gemini-2.5-flash-lite",
#         "safety_ratings": [],
#         "model_provider": "google_genai"
#     },
#     "type": "ai",
#     "name": null,
#     "id": "lc_run--019cd1cb-74f1-7b01-9a1b-276e16582b42-0",
#     "tool_calls": [],
#     "invalid_tool_calls": [],
#     "usage_metadata": {
#         "input_tokens": 2,
#         "output_tokens": 10,
#         "total_tokens": 12,
#         "input_token_details": {
#             "cache_read": 0
#         }
#     }
# }

# %%
results = result_json["organic_results"]

# %%
print(json.dumps(results,indent=3))
# Out:
# [
#    {
#       "position": 1,
#       "title": "Machine learning",
#       "result_id": "EQ8shYj8Ai8J",
#       "type": "Book",
#       "link": "https://books.google.com/books?hl=en&lr=&id=ctM-EAAAQBAJ&oi=fnd&pg=PR6&dq=machine+learning&ots=o_PkT3Qx_r&sig=zRKdIVneWMQB1TKFwR8Hv64rqMU",
#       "snippet": "\u2026 from data is called learning or training. The \u2026 machine learning is to find or approximate ground-truth. In this book, models are sometimes called learners, which are machine learning \u2026",
#       "publication_info": {
#          "summary": "ZH Zhou - 2021 - books.google.com",
#          "authors": [
#             {
#                "name": "ZH Zhou",
#                "link": "https://scholar.google.com/citations?user=rSVIHasAAAAJ&hl=en&oi=sra",
#                "author_id": "rSVIHasAAAAJ",
#                "serpapi_scholar_link": "https://serpapi.com/search.json?author_id=rSVIHasAAAAJ&engine=google_scholar_author&hl=en"
#             }
#          ]
#       },
# ...

# %%
def filter_search_results(results_list):
    filtered_output = []
    
    for item in results_list:
        pub_info = item.get("publication_info", {})
        inline_links = item.get("inline_links", {})
        
        filtered_item = {
            "title": item.get("title"),
            "link": item.get("link"),
            "snippet": item.get("snippet"),
            "authors": [a.get("name") for a in pub_info.get("authors", [])],
            "year": pub_info.get("summary", "").split(" - ")[1] if " - " in pub_info.get("summary", "") else None,
            "source": pub_info.get("summary", "").split(" - ")[-1] if " - " in pub_info.get("summary", "") else None,
            "citations": inline_links.get("cited_by", {}).get("total", 0)
        }
        filtered_output.append(filtered_item)
        
    return filtered_output

# Usage:
cleaned_data = filter_search_results(result_json["organic_results"])

# %%
cleaned_data
# Out:
# [{'title': 'Machine learning',
#   'link': 'https://books.google.com/books?hl=en&lr=&id=ctM-EAAAQBAJ&oi=fnd&pg=PR6&dq=machine+learning&ots=o_PkT3Qx_r&sig=zRKdIVneWMQB1TKFwR8Hv64rqMU',
#   'snippet': '… from data is called learning or training. The … machine learning is to find or approximate ground-truth. In this book, models are sometimes called learners, which are machine learning …',
#   'authors': ['ZH Zhou'],
#   'year': '2021',
#   'source': 'books.google.com',
#   'citations': 3612},
#  {'title': 'Machine learning',
#   'link': 'https://books.google.com/books?hl=en&lr=&id=Eyk5EAAAQBAJ&oi=fnd&pg=PA1&dq=machine+learning&ots=WRzMbcVmqO&sig=DIw4JfaJgaEsEdTPsL8GDeKpw58',
#   'snippet': 'MIT presents a concise primer on machine learning—computer programs that learn from data and the basis of applications like voice recognition and driverless cars. No in-depth …',
#   'authors': ['E Alpaydin'],
#   'year': '2021',
#   'source': 'books.google.com',
#   'citations': 1617},
# ...

# %%
from markitdown import MarkItDown

# %%
md = MarkItDown()

# %%
result = md.convert("temp.pdf")

# %%
print(result.text_content)
# Out:
# |     |     |     |     |     |     | PARTH     | GHADOLE       |             |     |     |     |     |
# | --- | --- | --- | --- | --- | --- | --------- | ------------- | ----------- | --- | --- | --- | --- |
# |     |     |     |     |     |     | +91 70287 | 99488 ⋄ Pune, | Maharashtra |     |     |     |     |
# Parth.Ghadole@outlook.com ⋄ www.linkedin.com/in/parth-ghadole-653819259
# PROFILE
# Computer Engineer with a strong interest in Python, Machine Learning, LLMs, and Chatbot development using
# Agentic AI. Skilled in SQL for database management and experienced in pyhton, with a primary focus on ML
# | and LLM | based | applications. |     |     |     |     |     |     |     |     |     |     |
# | ------- | ----- | ------------- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# EDUCATION
# | Pimpri | Chinchwad |     | College |     | of Engineering, |     | Pune (SPPU) |     |     |     |     |     |
# ...

# %%
url = "https://medium.com/@knish5790/roadmap-to-mastering-agentic-ai-bde9e0236997"

# %%
import requests
import io
from markitdown import MarkItDown

def convert_url_to_markdown(url):
    response = requests.get(url)
    response.raise_for_status()  
    
    file_stream = io.BytesIO(response.content)
    md = MarkItDown()

    result = md.convert(file_stream)
    
    return result.text_content
url = "https://www.princexml.com/samples/textbook/somatosensory.pdf"
markdown_output = convert_url_to_markdown(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[11], line 20
#      18     return result.text_content
#      19 url = "https://www.academia.edu/download/59817925/IRJET-V6I217620190621-73452-h5pwu7.pdf"
# ---> 20 markdown_output = convert_url_to_markdown(url)
#
# Cell In[11], line 12, in convert_url_to_markdown(url)
#       7 headers = {
#       8     "User-Agent": "Chrome"
#       9 }
#      11 response = requests.get(url, headers=headers)
# ---> 12 response.raise_for_status()
#      14 file_stream = io.BytesIO(response.content)
#      15 md = MarkItDown()
#
# File d:\Company\7. Langraph Reseach Agent\0.2.0\Research-Agent-with-Tools\.venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 x = await get_page_content(url)
#
# Cell In[18], line 5, in get_page_content(url)
#       4 async def get_page_content(url):
# ----> 5     async with async_playwright() as p:
#       6         # Launch the browser asynchronously
#       7         browser = await p.chromium.launch(headless=True)
#       8         page = await browser.new_page()
#
# File d:\Company\7. Langraph Reseach Agent\0.2.0\Research-Agent-with-Tools\.venv\Lib\site-packages\playwright\async_api\_context_manager.py:46, in PlaywrightContextManager.__aenter__(self)
#      44 if not playwright_future.done():
#      45     playwright_future.cancel()
# ---> 46 playwright = AsyncPlaywright(next(iter(done)).result())
#      47 playwright.stop = self.__aexit__  # type: ignore
#      48 return playwright
#
# ...
